# %%
import pandas as pd
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# # Data Cleanup
#
# Converted the job_posted_date column from string format to datetime format.

# %%
de_jobs = df[df['job_country'] == 'Germany']
de_jobs
# Out:
#               job_title_short  \
# 2               Data Engineer
# 34               Data Analyst
# 64        Senior Data Analyst
# 78      Senior Data Scientist
# 104         Software Engineer
# ...                       ...
# 785728  Senior Data Scientist
# 785729          Data Engineer
# 785732          Data Engineer
# 785735   Senior Data Engineer
# 785737           Data Analyst
#
#                                                 job_title        job_location  \
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...     Berlin, Germany
# 34      Data Analyst als Marketing Manager Automation ...   Erlangen, Germany
# 64                                    Senior Data Analyst     Berlin, Germany
# 78                                     Senior Data Expert     Berlin, Germany
# 104                   Senior Software Engineer - Metadata     Berlin, Germany
# ...                                                   ...                 ...
# ...

# %% [markdown]
# # Germany Data
#
# Filtered the dataset to include only jobs located in Germany.

# %%
job_counts = (
    de_jobs
    .groupby('job_title_short')
    .size()
    .sort_values(ascending=False)
)

job_counts
# Out:
# job_title_short
# Data Analyst                 7131
# Data Scientist               6745
# Data Engineer                6675
# Senior Data Engineer         2041
# Senior Data Scientist        1737
# Senior Data Analyst          1216
# Business Analyst              817
# Software Engineer             741
# Machine Learning Engineer     402
# Cloud Engineer                189
# dtype: int64

# %% [markdown]
# # Job Counts
#
# Shows the number of job postings for each job title in Germany.

# %%
salary_stats = (
    de_jobs
    .groupby('job_title_short')['salary_year_avg']
    .agg(['median', 'min', 'max', 'count'])
    .sort_values(by='median', ascending=False)
)

salary_stats
# Out:
#                              median      min       max  count
# job_title_short
# Senior Data Scientist      157500.0  80850.0  224500.0     21
# Data Engineer              147500.0  56700.0  200000.0     39
# Senior Data Engineer       147500.0  72900.0  155500.0     26
# Data Scientist             131560.0  56700.0  192000.0     41
# Senior Data Analyst        111175.0  57600.0  119400.0     15
# Data Analyst               103750.0  51014.0  200000.0     48
# Cloud Engineer              89100.0  80850.0  200000.0      7
# Business Analyst            89100.0  29900.0  126000.0     11
# Machine Learning Engineer   89100.0  44418.5  224500.0     39
# Software Engineer           84975.0  56700.0  177283.0     10

# %% [markdown]
# # Salary Statistics
#
# Displays median salary, minimum salary, maximum salary, and sample count for each role.

# %% [markdown]
# # Findings
#
# 1. The most common data roles in Germany are Data Analyst, Data Scientist, and Data Engineer.
#
# 2. Senior Data Scientist roles showed the highest median salary in this dataset.
#
# 3. Some job titles have very small sample sizes, so their salary statistics should be interpreted carefully.
#
# 4. Data Analyst, Data Scientist, and Data Engineer positions appear to make up a large portion of the German data job market.
