# %% [markdown]
# # Matplotlib Basics
#
# Visualizing median salaries for data jobs using Matplotlib.

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Loading
# Loaded the dataset from Hugging Face and converted it to a Pandas DataFrame.

# %%
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset["train"].to_pandas()

# %% [markdown]
# ## Data Cleanup
#
# Converted the job_posted_date column from string format to datetime format.

# %%
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

# %% [markdown]
# ## Salary Analysis
#
# Calculated median salary by job title and sorted the results.

# %%
job_salary = df.groupby("job_title_short")["salary_year_avg"].median().sort_values()

job_salary
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Software Engineer             99150.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# ## Visualization
#
# Created a horizontal bar chart showing median salaries across data job roles.

# %%
job_salary.plot(kind="barh")

plt.xlabel("Salary ($USD)")
plt.ylabel("")
plt.title("Median Salary by Job Title")

plt.show()

# %% [markdown]
# ## Key Findings
#
# 1. Senior Data Scientist roles showed the highest median salary in this dataset.
# 2. Senior Data Engineer and Data Scientist positions also ranked among the highest-paying roles.
# 3. Some job titles have relatively small sample sizes, so their salary statistics should be interpreted carefully.
# 4. Salaries generally increase with seniority, with senior-level data roles earning more than their non-senior counterparts.
